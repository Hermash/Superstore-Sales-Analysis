# %% [markdown]
# # Data loading

# %% [markdown]
# ## Import required libraries

# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# ## Load the dataset

# %%
DATA_PATH = Path("../data/raw/train.csv")

df = pd.read_csv(DATA_PATH)

# %% [markdown]
# ## Display the first five rows

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %% [markdown]
# ## Check the dataset dimensions

# %%
df.shape
# Out:
# (9800, 18)

# %% [markdown]
# ## Inspect data types and missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %% [markdown]
# ## Generate descriptive statistics

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %% [markdown]
# ## Check for missing values

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %% [markdown]
# ## Check for duplicate rows

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Check memory usage

# %%
df.memory_usage(deep=True)
# Out:
# Index               132
# Row ID            78400
# Order ID         617400
# Order Date       578200
# Ship Date        578200
# Ship Mode        605865
# Customer ID      558600
# Customer Name    610051
# Segment          566791
# Country          607600
# City             571515
# State            563445
# Postal Code       78400
# Region           527829
# Product ID       627200
# Category         605667
# Sub-Category     550630
# Product Name     862673
# Sales             78400
# dtype: int64

# %% [markdown]
# ## Initial observation:
#
# - The dataset contains 9,800 records and 18 columns.
# - The `Order Date` and `Ship Date` columns are stored as *object*.
# - Missing values are present in `Postal code` column.
# - No duplicate rows were found.
# - `Row ID` is an identifier and does not provide analytical value.
# - The average sales amount is **230.77**, while the median is only **54.49**, indicating a highly right-skewed distribution.
# - The maximum sales value (**22,638.48**) is significantly higher than the third quartile (**210.61**), suggesting the presence of high-value transactions or outliers.
# - Further analysis should include visualization of the sales distribution and investigation of potential outliers.
